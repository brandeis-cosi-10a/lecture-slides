# %% [markdown]
# # Hi there 2

# %%
print("this is slide 1")

# %%
print("this code will run after space")

# %% [markdown]
# # This is slide 2

# %%
print('Hello!\tI\'m a\ncomplicated\\interesting\n\”string\”')
print()
print("\ta\tb\tc")
print()
print("\\\\")
print()
print("'")
print()
print("\"\"\"")
print()
print("C:\nin\the downward spiral")
# Out:
# Hello!	I'm a
# complicated\interesting
# \”string\”
#
# 	a	b	c
#
# \\
#
# '
#
# """
#
# C:
# in	he downward spiral

# %% [markdown]
# ## Slide 3

# %%
# %load data_types.py
print("Hello world")
# Out:
# Hello world
